# %% [markdown]
# **1. What is Machine Learning ?**
#
# * Machine Learning is the field of study that gives computers the ability to learn without being explicitly programmed - coined by Arthur Samuel in 1959.
# - A computer program is said to learn from experience `E` with respect to some task `T` and some performance `P`, if its
# performance on task `T` as measured by `P` improves with experience `E`.
